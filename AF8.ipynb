# %% [markdown]
# <a href="https://colab.research.google.com/github/emy014gc/Inteligencia_Artificial-Equipo/blob/main/AF8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTELIGENCIA ARTIFICIAL Y REDES NEURONALES

# %% [markdown]
# Actividad 8: Redes Neuronales Convolucionales

# %% [markdown]
# *   Cesar Roel Martinez Espinoza 2059838 IMTC
# *   Emilio Garza Chavez          2101427 IMTC
# *   Jaime Alexander Robledo Sanchez 2092911 IMTC
# *   Oscar Alejandro Alcazar Garcia 2095211 IMTC
# *   Jose Fernando Villegas Jacobo 2115152 IMTC
#
# Grupo: 007 - Salon: 12206 - Hora: N5 - Fecha: 21/05/2026

# %%
# 1. Importar librerías
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
# 2. Cargar datos MNIST
(train_data, train_labels), (test_data, test_labels) = keras.datasets.mnist.load_data()

# %%
# 3. Preprocesamiento de datos

# Normalizar valores de píxeles
train_data = train_data.astype('float32') / 255.0
test_data = test_data.astype('float32') / 255.0

# Redimensionar para CNN -> (28,28,1)
train_data = train_data.reshape((60000, 28, 28, 1))
test_data = test_data.reshape((10000, 28, 28, 1))

# Convertir etiquetas a one-hot encoding
train_labels_cat = keras.utils.to_categorical(train_labels, 10)
test_labels_cat = keras.utils.to_categorical(test_labels, 10)

# %%
# 4. Definir modelo CNN
model = keras.Sequential([

    # Primera capa convolucional
    keras.layers.Conv2D(
        32,
        (3,3),
        activation='relu',
        input_shape=(28,28,1)
    ),

    # Pooling
    keras.layers.MaxPooling2D((2,2)),

    # Segunda capa convolucional
    keras.layers.Conv2D(
        64,
        (3,3),
        activation='relu'
    ),

    # Segundo pooling
    keras.layers.MaxPooling2D((2,2)),

    # Aplanar datos
    keras.layers.Flatten(),

    # Capa oculta
    keras.layers.Dense(64, activation='relu'),

    # Capa de salida
    keras.layers.Dense(10, activation='softmax')
])

# %%
# 5. Compilar modelo
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# 6. Entrenar modelo
history = model.fit(
    train_data,
    train_labels_cat,
    epochs=10,
    batch_size=128,
    validation_data=(test_data, test_labels_cat),
    verbose=1
)
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 44s 92ms/step - accuracy: 0.9322 - loss: 0.2339 - val_accuracy: 0.9780 - val_loss: 0.0696
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 45s 97ms/step - accuracy: 0.9821 - loss: 0.0591 - val_accuracy: 0.9840 - val_loss: 0.0506
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 92ms/step - accuracy: 0.9871 - loss: 0.0425 - val_accuracy: 0.9872 - val_loss: 0.0393
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 92ms/step - accuracy: 0.9899 - loss: 0.0332 - val_accuracy: 0.9898 - val_loss: 0.0326
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.9913 - loss: 0.0276 - val_accuracy: 0.9903 - val_loss: 0.0323
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 89ms/step - accuracy: 0.9929 - loss: 0.0225 - val_accuracy: 0.9893 - val_loss: 0.0307
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 92ms/step - accuracy: 0.9941 - loss: 0.0181 - val_accuracy: 0.9900 - val_loss: 0.0315
# Epoch 8/10
# ...

# %%
# 7. Evaluar modelo
test_loss, test_acc = model.evaluate(
    test_data,
    test_labels_cat,
    verbose=0
)
print(f'\nExactitud en prueba: {test_acc:.4f}')
# Out:
# Exactitud en prueba: 0.9915

# %%
# 8. Realizar 5 predicciones
predicciones = model.predict(test_data[:5])

print('\n--- 5 predicciones vs valores reales ---')

for i in range(5):

    pred = np.argmax(predicciones[i])
    real = test_labels[i]

    print(f'Predicción: {pred} | Valor real: {real}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#
# --- 5 predicciones vs valores reales ---
# Predicción: 7 | Valor real: 7
# Predicción: 2 | Valor real: 2
# Predicción: 1 | Valor real: 1
# Predicción: 0 | Valor real: 0
# Predicción: 4 | Valor real: 4
